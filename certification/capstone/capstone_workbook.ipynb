# %% [markdown]
# # Final Capstone Workbook — AI NOC Mini-Platform
#
# **Network LLM Engineer Certification**
#
# ### Learning / assessment objectives
# - Integrate the complete course
# - Demonstrate measurable and safe Network AI engineering
# - Defend architectural choices

# %% [markdown]
# ## 1. Problem statement
# Describe the target NOC workflow and users. State what the system will **not** automate.

# %% [markdown]
# ## 2. Architecture
# Insert or link your architecture diagram. Label:
# - model(s),
# - retrieval,
# - tools,
# - data stores,
# - agent/orchestrator,
# - validators,
# - digital twin,
# - human approval,
# - observability.

# %% [markdown]
# ## 3. Evaluation matrix

# %%
import pandas as pd
matrix = pd.DataFrame([
    {"system":"base_prompt","correctness":None,"faithfulness":None,"unsafe_rate":None,"schema_valid":None,"latency_ms":None},
    {"system":"base_rag","correctness":None,"faithfulness":None,"unsafe_rate":None,"schema_valid":None,"latency_ms":None},
    {"system":"adapted","correctness":None,"faithfulness":None,"unsafe_rate":None,"schema_valid":None,"latency_ms":None},
    {"system":"adapted_rag_tools","correctness":None,"faithfulness":None,"unsafe_rate":None,"schema_valid":None,"latency_ms":None},
])
display(matrix)

# %% [markdown]
# ## 4. Required failure-injection tests
#
# Document behavior when:
# - retrieval returns irrelevant context,
# - tool times out,
# - device is unknown,
# - prompt injection appears in a runbook,
# - model emits malformed structure,
# - digital twin contradicts the model proposal,
# - approval is denied.

# %% [markdown]
# ## 5. Release decision
#
# State one of:
# - **Ready for limited pilot**
# - **Not ready**
#
# Justify with evidence. Certification rewards a correct non-deployment decision more than an unjustified launch.
