# %% [markdown]
# # Quiz 6 — Module Knowledge Check
#
# **Professional Certification Assessment**
#
# ### Learning / assessment objectives
# - Demonstrate conceptual understanding
# - Explain why the correct answer is correct
# - Identify one networking example per concept

# %% [markdown]
# ## Instructions
#
# - Closed notes recommended for the first attempt.
# - 80% is the target score.
# - After grading, explain every incorrect answer in your own words.
# - The score is only one part of certification; practical work carries more weight.

# %%
QUESTIONS = [['Which mechanism should approve a production change?', ['Model confidence alone', 'Policy/authorization plus human or governed approval', 'Vector similarity', 'LoRA rank'], 1], ['Why use a digital twin?', ['To replace all production telemetry', 'To test selected properties in an isolated environment', 'To increase token count', 'To store embeddings'], 1], ['What is TTFT?', ['Training time for fine-tuning', 'Time to first token', 'Total tool failure threshold', 'Token transfer format'], 1], ['What is a release gate?', ['A set of promotion criteria before deployment', 'A prompt template', 'An attention mask', 'A retrieval chunk'], 0], ['What should be traced in production?', ['Only final answer', 'Model, retrieval, tools, validators, approvals and outcomes', 'Only GPU utilization', 'Only prompts'], 1], ['What should CI test after changing a retrieval index?', ['Only GPU temperature', 'Retrieval and end-to-end golden-set metrics', 'Only training loss', 'Nothing'], 1], ['What is indirect prompt injection?', ['A model quantization error', 'Malicious instructions arriving through retrieved/tool content', 'A network loop', 'A tokenizer bug'], 1], ['Which runtime/ecosystem is strongly associated with GGUF?', ['llama.cpp', 'Neo4j', 'Kafka', 'Pandas'], 0]]

def run_quiz():
    score = 0
    for i, (q, options, answer) in enumerate(QUESTIONS, 1):
        print(f"\n{i}. {q}")
        for j, opt in enumerate(options):
            print(f"   {j}: {opt}")
        raw = input("Your answer (number): ").strip()
        try:
            choice = int(raw)
        except ValueError:
            choice = -1
        if choice == answer:
            print("Correct")
            score += 1
        else:
            print("Incorrect. Correct answer:", answer, "-", options[answer])
    pct = 100 * score / len(QUESTIONS)
    print(f"\nScore: {score}/{len(QUESTIONS)} = {pct:.1f}%")
    return pct

# run_quiz()

# %% [markdown]
# ## Reflection
#
# For every incorrect answer, write:
# 1. the definition,
# 2. a networking example,
# 3. one common misconception.
