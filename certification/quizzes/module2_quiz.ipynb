# %% [markdown]
# # Quiz 2 — Module Knowledge Check
#
# **Professional Certification Assessment**
#
# ### Learning / assessment objectives
# - Demonstrate conceptual understanding
# - Explain why the correct answer is correct
# - Identify one networking example per concept

# %% [markdown]
# ## Instructions
#
# - Closed notes recommended for the first attempt.
# - 80% is the target score.
# - After grading, explain every incorrect answer in your own words.
# - The score is only one part of certification; practical work carries more weight.

# %%
QUESTIONS = [['What is the main purpose of RAG?', ['Change model weights', 'Retrieve external context at inference time', 'Quantize a model', 'Train a reward model'], 1], ['Which retrieval mode is strongest for exact error codes?', ['Dense only', 'Sparse/keyword', 'Temperature sampling', 'LoRA'], 1], ['What is a reranker?', ['A second-stage relevance ordering component', 'A tokenizer', 'A GPU scheduler', 'A reward model for RL'], 0], ['Why is GraphRAG attractive for networking?', ['Networks are naturally relational graphs', 'It removes all hallucinations', 'It replaces NetBox', 'It is just a bigger vector DB'], 0], ['What should hold current interface state?', ['Model weights', 'RAG/tool source of truth', 'LoRA rank', 'Tokenizer vocabulary'], 1], ['What does reciprocal rank fusion combine?', ['Model weights', 'Multiple ranked retrieval lists', 'LoRA adapters', 'Tool schemas'], 1], ['What is HyDE used for?', ['Quantization', 'Retrieval using a hypothetical document/answer representation', 'RL reward modeling', 'Model serving'], 1]]

def run_quiz():
    score = 0
    for i, (q, options, answer) in enumerate(QUESTIONS, 1):
        print(f"\n{i}. {q}")
        for j, opt in enumerate(options):
            print(f"   {j}: {opt}")
        raw = input("Your answer (number): ").strip()
        try:
            choice = int(raw)
        except ValueError:
            choice = -1
        if choice == answer:
            print("Correct")
            score += 1
        else:
            print("Incorrect. Correct answer:", answer, "-", options[answer])
    pct = 100 * score / len(QUESTIONS)
    print(f"\nScore: {score}/{len(QUESTIONS)} = {pct:.1f}%")
    return pct

# run_quiz()

# %% [markdown]
# ## Reflection
#
# For every incorrect answer, write:
# 1. the definition,
# 2. a networking example,
# 3. one common misconception.
