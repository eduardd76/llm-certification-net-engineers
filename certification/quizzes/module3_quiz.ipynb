# %% [markdown]
# # Quiz 3 — Module Knowledge Check
#
# **Professional Certification Assessment**
#
# ### Learning / assessment objectives
# - Demonstrate conceptual understanding
# - Explain why the correct answer is correct
# - Identify one networking example per concept

# %% [markdown]
# ## Instructions
#
# - Closed notes recommended for the first attempt.
# - 80% is the target score.
# - After grading, explain every incorrect answer in your own words.
# - The score is only one part of certification; practical work carries more weight.

# %%
QUESTIONS = [['What should SFT data primarily teach?', ['Dynamic inventory', 'Stable behavior and task mappings', "Today's BGP neighbors", 'Secrets'], 1], ['What is LoRA?', ['A vector DB', 'Low-rank trainable updates on a frozen base model', 'A tokenizer', 'An RL algorithm'], 1], ['What is QLoRA?', ['LoRA on a quantized base model', 'Quantized RAG', 'RLHF with queries', 'GraphRAG with LoRA'], 0], ['Why is falling training loss insufficient?', ['It does not prove held-out correctness or safety', 'Loss is irrelevant', 'Loss only measures latency', 'It means the model is broken'], 0], ['What is train/test leakage?', ['Using the same GPU twice', 'Test information entering training/development', 'Using mixed precision', 'A bad tokenizer'], 1], ['Which is primarily a model file/runtime ecosystem format?', ['DPO', 'GGUF', 'RAG', 'MCP'], 1], ['Which method uses activation behavior to guide weight quantization?', ['AWQ', 'DPO', 'PPO', 'RRF'], 0]]

def run_quiz():
    score = 0
    for i, (q, options, answer) in enumerate(QUESTIONS, 1):
        print(f"\n{i}. {q}")
        for j, opt in enumerate(options):
            print(f"   {j}: {opt}")
        raw = input("Your answer (number): ").strip()
        try:
            choice = int(raw)
        except ValueError:
            choice = -1
        if choice == answer:
            print("Correct")
            score += 1
        else:
            print("Incorrect. Correct answer:", answer, "-", options[answer])
    pct = 100 * score / len(QUESTIONS)
    print(f"\nScore: {score}/{len(QUESTIONS)} = {pct:.1f}%")
    return pct

# run_quiz()

# %% [markdown]
# ## Reflection
#
# For every incorrect answer, write:
# 1. the definition,
# 2. a networking example,
# 3. one common misconception.
